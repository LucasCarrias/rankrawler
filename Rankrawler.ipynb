# %%
from requests import Session
from bs4 import BeautifulSoup
from urllib.parse import urlparse
from datetime import datetime
from math import log10
from random import choice
import pandas as pd
import time
import re
import pymysql
import pickle

# %% [markdown]
# Conexão com o banco de dados

# %%
conn = pymysql.connect(host='127.0.0.1', user='root', passwd='210909', db='mysql', charset='utf8')
cur = conn.cursor()
cur.execute("USE rankrawlerdb")
# Out:
# 0

# %% [markdown]
# Ajuste do tamanho da coluna no Pandas

# %%
pd.set_option('max_colwidth', 300)

# %% [markdown]
# Classe de Dominío de cada url. (Abandonada)

# %%
class Domain:
    
    def __init__(self, netloc, last_access=0, ignore=False):
        self.netloc = netloc
        self.last_access = last_access
        self.ignore = ignore
        
    def can_access(self, wait_time=1.5):
        return (time.time() - self.last_access) > wait_time

# %% [markdown]
# Classe de Página de cada url

# %%
class Page:    
    def __init__(self, url):      
        self.url = url
        self.domain = urlparse(url).netloc
        self.internal_links = set()
        self.external_links = set()
        self.links = []
        
    def get_page_info(self,search_keyword=''):
        #modificar o user_agent ajuda a deixar o bot um pouco mais humano
        user_agent = {'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.122 Safari/537.36'}
        session = Session()
        certificate = '/home/lucascarrias/.local/lib/python3.6/site-packages/certifi/cacert.pem' #certificado de cada usuário
        try:
            response = session.get(self.url, headers=user_agent, verify=certificate, timeout=50)
            self.status_code = response.status_code
            self.last_access = datetime.now()
            print(response)
            if response.status_code < 400:                
                bs = BeautifulSoup(response.text, 'html5lib')
                if bs:
                    self.lang = self.get_tag_attr_text(bs, 'html', 'lang')
                    self.title = self.get_tag_text(bs, 'title')
                    self.h1 = self.get_tag_text(bs, 'h1')
                    self.description = self.get_tag_attr_text(bs, 'meta', 'name', 'description', target='content')
                    self.keywords = self.get_tag_attr_text(bs, 'meta', 'name', 'keywords', target='content')
                    self.has_viewport = True if self.get_tag_attr_text(bs, 'meta', 'name', 'viewport') is not None else False
        
                    if search_keyword != '':
                        self.search_results =  self.get_search_results(bs, search_keyword)
                        self.match_sample = self.get_match_sample(bs, search_keyword)
                    
                    self.get_links(bs)
        except:
            """Em todos os casos testados os erros foram chamados quando a página se recusava a dar uma resposta de acordo
            com o esperado. Esta solução serviu para acelerar o desenvolvimento do trabalho"""
            self.status_code = 403                    
        finally:
            session.close()
        
    
    def get_search_results(self, bs_obj, keyword):
        macthes = {'in_h1':False,'in_title':False,'in_description':False ,'body':0}
        for word in set(keyword.split(' ')):
            if not macthes['in_h1'] and self.h1 is not None:
                macthes['in_h1'] = len(re.findall(f'(?i){word}', self.h1)) > 0
            if not macthes['in_title'] and self.title is not None:
                macthes['in_title'] = len(re.findall(f'(?i){word}', self.title)) > 0
            if not macthes['in_description'] and self.description is not None:
                macthes['in_description'] = len(re.findall(f'(?i){word}', self.description)) > 0
            if bs_obj.find('body') is not None:
                macthes['body'] += len(re.findall(f'(?i){word}', bs_obj.find('body').get_text()))        
        macthes['body'] = int(macthes['body']/len(set(keyword.split(' '))))        
        return macthes
    
    def get_links(self, bs_obj):
        if bs_obj is None:
            return
        links = set()
        internal_links = set()
        external_links = set()
        raw_url = f"{urlparse(self.url).scheme}://{self.domain}"
        
        if bs_obj.find("a") is not None:            
            for link in bs_obj.find_all("a", href=re.compile(r"^\/?^[^#& ]+")):
                result = re.match(r"^\/?^[^#&]+",link.attrs["href"])[0]
                if re.match(r'^//', result):
                    self.external_links.add("http:" + result)
                elif result[0] == "/":
                    self.internal_links.add(raw_url + result)
                else:
                    if re.match(r'^https?', result) is not None:
                        self.external_links.add(result)
                    elif re.match(r'^www', result) is not None:
                        self.external_links.add("https://" + result)
                    else:
                        self.internal_links.add("/".join([raw_url, result]))
        self.links = list(self.internal_links | self.external_links)
    
    def print_info(self):
        for key, item in self.__dict__.items():
            print(str(key) + ":" + str(item))
    
    def get_match_sample(self, bs_obj, keyword):
        if self.search_results['in_title']:
            return self.title
        elif self.search_results['in_description']:
            return self.description
        elif self.search_results['in_h1']:
            return self.h1
        elif self.search_results['body'] > 0:
            matches = re.findall(fr'(?i)\b{keyword}[^.\n<]+', bs_obj.find('body').get_text())
            if len(matches) > 0:
                return choice(matches).strip()
        return None
        
        
    @staticmethod
    def get_tag_text(bs_obj, tag):
        if bs_obj.find(tag) is not None:
            return bs_obj.find(tag).get_text().strip()
        return None
    
    @staticmethod
    def get_tag_attr_text(bs_obj, tag, attr, attr_value='.*', target=''):
        result = bs_obj.find(tag, {f"{attr}":re.compile(f'(?i){attr_value}')})
        if result is not None:            
            if target != '':
                return result[target]
            return result[attr]
        return None

# %% [markdown]
# Classe do Crawler

# %%
class Scraper:
     
    def __init__(self,*, ignored_domains=[]):   
        self.visited_pages = set()
        self.visited_urls = set()
        self.ignored_domains = ignored_domains
        self.found_domains = set()
        self.last_visited_domain = None
        
        
    def crawl(self,url, keyword, layer=1):
        if layer == 0:
            conn.commit()
            return
        start = time.perf_counter()
        print(f"Looking at ({layer}): " + url)
        self.update_domains()
        page = Page(url)
        
        if page.domain == self.last_visited_domain:
            print('Waiting...')
            time.sleep(2)
        if page.domain in self.ignored_domains:
            return
        
        page.get_page_info(keyword)
        
        self.visited_pages.add(page)
        self.last_visited_domain = page.domain
        
        if page.status_code == 403:
            self.found_domains.add(Domain(page.domain, time.time(), ignore=True))
            self.ignored_domains.append(page.domain)
            self.save_domain(page.domain, True)
        elif page.status_code < 400:
            self.save_domain(page.domain)
            self.save_config(url, keyword, layer)
            self.save_page(page)
            self.save_search(keyword, layer, page)            
        
        for url in page.links:
            if url not in self.visited_urls:
                self.visited_urls.add(url)
                self.crawl(url, keyword, layer-1)
                    
            
        print(f"Searching for {keyword} on layer {layer} done in {round(time.perf_counter() - start, 2)} second(s)")
    
    def get_ranking(self, keyword):
        cur.execute('SELECT netloc, url,' +
            'hasTitle, hasDescription, hasH1, hasKeywords, hasViewport,' +
            'matchesInBody, keywordInDescription, keywordInH1, keywordInTitle ' +
            f"from result natural join search natural join config natural join page natural join domain where keyword = '{keyword}'")
        result = cur.fetchall()
        df = pd.DataFrame(list(set(result)), columns= 'netloc, url, hasTitle, hasDescription, hasH1,'
                          ' hasKeywords, hasViewport, matchesInBody, keywordInDescription, keywordInH1, keywordInTitle'.split(', '))
        knn = pickle.load(open('knn-classifier.plk', 'rb'))
        df['matchesInBody'] = df['matchesInBody'].apply(lambda x : round(log10(x+1),2))
        df['score'] = [proba[1] for proba in knn.predict_proba(df[df.columns[2:]])] + df['matchesInBody']
        df['score'] = df['score'].apply(lambda x: round((x/max(df['score']))*100,2))
        return df[['netloc','url','score']].sort_values('score', ascending=False)
    
    def get_search_history(self):
        cur.execute("SELECT keyword FROM config group by keyword");
        return cur.fetchall()
    
    def update_domains(self):
        cur.execute(f"SELECT * FROM domain where blackListed = 1")
        for bad_domain in cur.fetchall():
            self.ignored_domains.append(bad_domain[1])
            
    @staticmethod
    def save_domain(netloc, ignore=False):
        cur.execute(f"SELECT netloc FROM domain where netloc like '{netloc}'")
        if not cur.fetchone():
            cur.execute(f"INSERT INTO domain (netloc, blackListed) values ('{netloc}', {1 if ignore else 0})")

    @staticmethod
    def save_config(url, keyword, layers):
        cur.execute(f"SELECT * FROM config where keyword like '{keyword}' and startingUrl like '{url}' and layers = {layers}")
        if not cur.fetchone():
            cur.execute(f"INSERT INTO config (startingUrl, keyword, layers) values ('{url}', '{keyword}', {layers})")

    @staticmethod
    def save_page(found_page):    
        cur.execute(f"SELECT idDomain FROM domain where netloc like '{found_page.domain}'")
        domain_id = cur.fetchone()[0]
        cur.execute("INSERT INTO page (url, idDomain, hasTitle, hasH1, hasDescription, hasKeywords, hasViewport) values " \
                    f"('{found_page.url}', {domain_id}," \
                    f"{1 if found_page.title else 0},{1 if found_page.h1 else 0}, {1 if found_page.description else 0}, " \
                    f"{1 if found_page.keywords else 0}, {1 if found_page.has_viewport else 0})")

    @staticmethod
    def save_search(keyword, layer, found_page):
        cur.execute(f"SELECT idConfig FROM config where keyword like '{keyword}'")
        config_id = cur.fetchone()[0]
        cur.execute(f"SELECT idPage FROM page where url like '{found_page.url}'")
        page_id = cur.fetchone()[0]
        cur.execute(f"INSERT INTO search (idConfig, idPage, layer) values ({config_id}, {page_id}, {layer})")

        cur.execute(f"SELECT max(idSearch) FROM search")
        search_id = cur.fetchone()[0]
        results = found_page.search_results
        cur.execute("INSERT INTO result (idSearch, matchesInBody, keywordInTitle, keywordInDescription, keywordInH1) values " \
                    f"({search_id}, {results['body']}, {1 if results['in_title'] else 0}, {1 if results['in_description'] else 0}, {1 if results['in_h1'] else 0})")

# %%
scraper = Scraper(ignored_domains=['www.facebook.com', 'www.twitter.com'])

# %%
try:
    scraper.crawl("https://en.wikipedia.org/wiki/Clube_de_Regatas_do_Flamengo", "flamengo", 2)
except KeyboardInterrupt:
    print("Interrompido pelo o Usuário.")
    conn.commit()
# Out:
# Looking at (2): https://en.wikipedia.org/wiki/Clube_de_Regatas_do_Flamengo
# <Response [200]>
# Looking at (1): https://en.wikipedia.org/wiki/Gerson_(footballer,_born_1997)
# Waiting...
# <Response [200]>
# Searching for flamengo on layer 1 done in 3.3 second(s)
# Looking at (1): https://en.wikipedia.org/wiki/FIFA_eligibility_rules
# Waiting...
# <Response [200]>
# Searching for flamengo on layer 1 done in 3.28 second(s)
# Looking at (1): https://en.wikipedia.org/wiki/Bebeto
# Waiting...
# <Response [200]>
# Searching for flamengo on layer 1 done in 3.76 second(s)
# Looking at (1): https://en.wikipedia.org/wiki/1984_Copa_Libertadores
# Waiting...
# <Response [200]>
# Searching for flamengo on layer 1 done in 3.05 second(s)
# Looking at (1): https://en.wikipedia.org/wiki/1974_Campeonato_Brasileiro_S%C3%A9rie_A
# Waiting...
# <Response [200]>
# Searching for flamengo on layer 1 done in 3.57 second(s)
# Looking at (1): https://en.wikipedia.org/wiki/Category:All_articles_with_dead_external_links
# Waiting...
# <Response [200]>
# Searching for flamengo on layer 1 done in 3.29 second(s)
# Looking at (1): https://en.wikipedia.org/wiki/Category:Articles_with_dead_external_links_from_March_2017
# Waiting...
# <Response [200]>
# Searching for flamengo on layer 1 done in 3.16 second(s)
# Looking at (1): https://en.wikipedia.org/wiki/2018_Copa_Libertadores_group_stage
# Waiting...
# <Response [200]>
# Searching for flamengo on layer 1 done in 4.24 second(s)
# Looking at (1): https://en.wikipedia.org/wiki/1988_Campeonato_Carioca
# Waiting...
# <Response [200]>
# Searching for flamengo on layer 1 done in 3.2 second(s)
# Looking at (1): https://en.wikipedia.org/wiki/Centenary
# Waiting...
# <Response [200]>
# Searching for flamengo on layer 1 done in 3.23 second(s)
# Looking at (1): https://en.wikipedia.org/wiki/Coronel_Bolognesi
# Waiting...
# <Response [200]>
# Searching for flamengo on layer 1 done in 3.02 second(s)
# Looking at (1): https://en.wikipedia.org/wiki/Movile_(company)
# Waiting...
# <Response [200]>
# Searching for flamengo on layer 1 done in 3.23 second(s)
# Looking at (1): https://en.wikipedia.org/wiki/FC_Bayern_Munich
# Waiting...
# <Response [200]>
# Searching for flamengo on layer 1 done in 4.83 second(s)
# Looking at (1): https://en.wikipedia.org/wiki/Supercopa_Libertadores
# Waiting...
# <Response [200]>
# Searching for flamengo on layer 1 done in 3.15 second(s)
# Looking at (1): https://da.wikipedia.org/wiki/Clube_de_Regatas_do_Flamengo
# <Response [200]>
# Searching for flamengo on layer 1 done in 1.27 second(s)
# Looking at (1): https://en.wikipedia.org/wiki/Vitor_Gabriel_(footballer,_born_2000)
# <Response [200]>
# Searching for flamengo on layer 1 done in 0.94 second(s)
# Looking at (1): https://commons.wikimedia.org/wiki/Clube_de_Regatas_do_Flamengo_kits
# <Response [200]>
# Searching for flamengo on layer 1 done in 1.17 second(s)
# Looking at (1): https://en.wikipedia.org/wiki/List_of_Brazilian_football_transfers_winter_2019%E2%80%9320
# <Response [200]>
# Searching for flamengo on layer 1 done in 2.17 second(s)
# Looking at (1): https://en.wikipedia.org/wiki/Category:Football_clubs_in_Rio_de_Janeiro_(city)
# Waiting...
# <Response [200]>
# Searching for flamengo on layer 1 done in 3.03 second(s)
# Looking at (1): http://flapedia.com.br/Clube_Atl%C3%A9tico_Mineiro
# Searching for flamengo on layer 1 done in 0.03 second(s)
# Looking at (1): https://en.wikipedia.org/wiki/File:Ilha_do_urubu.jpeg
# <Response [200]>
# Searching for flamengo on layer 1 done in 1.28 second(s)
# Looking at (1): https://en.wikipedia.org/wiki/2015_Clube_de_Regatas_do_Flamengo_season
# Waiting...
# <Response [200]>
# Searching for flamengo on layer 1 done in 3.99 second(s)
# Looking at (1): https://esportes.estadao.com.br/noticias/futebol,flamengo-assina-com-a-olympikus-por-cerca-de-r-170-milhoes,181703
# <Response [200]>
# Searching for flamengo on layer 1 done in 0.97 second(s)
# Looking at (1): https://en.wikipedia.org/wiki/Club_Deportivo_Palestino
# <Response [200]>
# Searching for flamengo on layer 1 done in 1.32 second(s)
# Looking at (1): https://en.wikipedia.org/wiki/1996_Copa_do_Brasil
# Waiting...
# <Response [200]>
# Searching for flamengo on layer 1 done in 3.28 second(s)
# Looking at (1): http://www.ligafibaamericas.com/noticiasread4.asp?r=0171867B746241EA8536C8218B2E84F6
# <Response [200]>
# Searching for flamengo on layer 1 done in 1.28 second(s)
# Looking at (1): https://en.wikipedia.org/wiki/File:Flamengo_braz_logo.svg
# <Response [200]>
# Searching for flamengo on layer 1 done in 1.3 second(s)
# Looking at (1): http://espn.com.br/noticia/443420_campeoes-mundiais-no-basquete-e-futebol-fla-se-iguala-a-real-e-barca
# <Response [200]>
# Searching for flamengo on layer 1 done in 1.74 second(s)
# Looking at (1): https://en.wikipedia.org/wiki/Futsal
# <Response [200]>
# Searching for flamengo on layer 1 done in 2.39 second(s)
# Looking at (1): https://en.wikipedia.org/w/index.php?title=Americano_Football_Club
# Waiting...
# <Response [404]>
# Searching for flamengo on layer 1 done in 3.17 second(s)
# Looking at (1): https://en.wikipedia.org/wiki/Help:IPA/Portuguese
# Waiting...
# <Response [200]>
# Searching for flamengo on layer 1 done in 3.31 second(s)
# Looking at (1): http://globoesporte.globo.com/futebol/noticia/2011/03/flamengo-cria-time-feminino-de-futebol-e-sonha-com-marta.html
# <Response [200]>
# Searching for flamengo on layer 1 done in 0.78 second(s)
# Looking at (1): https://en.wikipedia.org/wiki/Universidad_de_Los_Andes_F.C.
# <Response [200]>
# Searching for flamengo on layer 1 done in 1.07 second(s)
# Looking at (1): http://www.sambafoot.com/en/news/40523_flamengo_approve____150_million_adidas_kit_deal.html
# <Response [200]>
# Searching for flamengo on layer 1 done in 2.68 second(s)
# Looking at (1): https://en.wikipedia.org/wiki/Proclamation_of_the_Republic_(Brazil)
# <Response [200]>
# Searching for flamengo on layer 1 done in 1.38 second(s)
# Looking at (1): https://en.wikipedia.org/wiki/Caju,_Rio_de_Janeiro
# Waiting...
# <Response [200]>
# Searching for flamengo on layer 1 done in 3.09 second(s)
# Looking at (1): https://en.wikipedia.org/wiki/2008_Copa_Libertadores_knockout_stages
# Waiting...
# <Response [200]>
# Searching for flamengo on layer 1 done in 3.68 second(s)
# Looking at (1): http://globoesporte.globo.com/futebol/times/flamengo/noticia/2015/07/fla-anuncia-parceira-com-marinha-para-disputar-o-brasileiro-feminino.html
# <Response [200]>
# Searching for flamengo on layer 1 done in 0.99 second(s)
# Looking at (1): https://globoesporte.globo.com/futebol/times/flamengo/noticia/apos-confusao-no-hotel-do-independiente-conmebol-vai-abrir-processo-contra-o-fla.ghtml
# Waiting...
# <Response [200]>
# Searching for flamengo on layer 1 done in 2.77 second(s)
# Looking at (1): https://en.wikipedia.org/w/index.php?title=Template:Campeonato_Carioca
# <Response [200]>
# Searching for flamengo on layer 1 done in 1.17 second(s)
# Looking at (1): http://globoesporte.globo.com/futebol/times/flamengo/noticia/2017/01/alcapao-do-fla-tera-setor-sem-cadeira-e-arquibancada-6-metros-do-campo.html
# <Response [200]>
# Searching for flamengo on layer 1 done in 0.42 second(s)
# Looking at (1): https://interativos.globoesporte.globo.com/futebol/times/flamengo/especial/ficou-marcado-na-historia
# <Response [200]>
# Searching for flamengo on layer 1 done in 0.7 second(s)
# Looking at (1): http://secure.rio2016.com/maracana/o-novo-estadio-do-maracana-tera-capacidade-para-78639-espectadores
# Searching for flamengo on layer 1 done in 0.14 second(s)
# Looking at (1): https://en.wikipedia.org/wiki/Walkover
# <Response [200]>
# Searching for flamengo on layer 1 done in 0.95 second(s)
# Looking at (1): http://globoesporte.globo.com/sp/sorocaba/futebol/noticia/2016/05/flamengo-vence-rio-preto-fora-de-casa-e-e-campeao-do-brasileirao-feminino.html
# <Response [200]>
# Searching for flamengo on layer 1 done in 1.05 second(s)
# Looking at (1): https://www.flamengo.com.br/noticias/futebol/jorge-jesus-e-o-novo-tecnico-do-flamengo
# <Response [200]>
# Searching for flamengo on layer 1 done in 1.23 second(s)
# Looking at (1): https://oglobo.globo.com/esportes/incendio-deixa-dez-mortos-no-ninho-do-urubu-centro-de-treinamento-do-flamengo-23437241
# <Response [200]>
# Searching for flamengo on layer 1 done in 2.43 second(s)
# Looking at (1): http://trivela.uol.com.br/como-os-timacos-de-fla-e-galo-criaram-maior-rivalidade-interestadual-brasil/
# <Response [200]>
# Searching for flamengo on layer 1 done in 1.05 second(s)
# Looking at (1): https://globoesporte.globo.com/futebol/times/flamengo/noticia/estreia-com-derrota-do-uniforme-cor-cinza-revive-a-maldicao-das-terceiras-camisas-do-flamengo.ghtml
# <Response [200]>
# Searching for flamengo on layer 1 done in 0.96 second(s)
# Looking at (1): https://en.wikipedia.org/wiki/M%C3%A1rcio_Braga
# <Response [200]>
# Searching for flamengo on layer 1 done in 1.09 second(s)
# Looking at (1): https://en.wiktionary.org/wiki/Flamengo
# <Response [404]>
# Searching for flamengo on layer 1 done in 1.33 second(s)
# Looking at (1): https://en.wikipedia.org/wiki/Estadio_Centenario
# <Response [200]>
# Searching for flamengo on layer 1 done in 1.33 second(s)
# Looking at (1): https://en.wikipedia.org/wiki/2014_FIBA_Intercontinental_Cup
# Waiting...
# <Response [200]>
# Searching for flamengo on layer 1 done in 3.56 second(s)
# Looking at (1): https://en.wikipedia.org/wiki/Evaristo_de_Macedo
# Waiting...
# <Response [200]>
# Searching for flamengo on layer 1 done in 4.97 second(s)
# Looking at (1): https://en.wikipedia.org/wiki/G.D._Estoril_Praia
# Waiting...
# <Response [200]>
# Searching for flamengo on layer 1 done in 3.55 second(s)
# Looking at (1): http://flamengo.com.br
# <Response [200]>
# Searching for flamengo on layer 1 done in 2.21 second(s)
# Looking at (1): https://en.wikipedia.org/wiki/2015%E2%80%9316_NBB_season
# <Response [200]>
# Searching for flamengo on layer 1 done in 1.19 second(s)
# Looking at (1): http://tools.wmflabs.org/geohack/geohack.php?pagename=Clube_de_Regatas_do_Flamengo
# <Response [400]>
# Searching for flamengo on layer 1 done in 1.33 second(s)
# Looking at (1): https://en.wikipedia.org/wiki/Alex_Muralha
# <Response [200]>
# Searching for flamengo on layer 1 done in 1.5 second(s)
# Looking at (1): https://en.wikipedia.org/wiki/AEK_B.C.
# Waiting...
# <Response [200]>
# Searching for flamengo on layer 1 done in 4.71 second(s)
# Looking at (1): https://futebolnacional.com.br/infobol/matchdetails.jsp?code=CE458392AC0176169E89E60A7C00AB4D
# <Response [404]>
# Searching for flamengo on layer 1 done in 1.13 second(s)
# Looking at (1): https://en.wikipedia.org/wiki/Campeonato_Brasileiro_de_Basquete
# <Response [200]>
# Searching for flamengo on layer 1 done in 1.6 second(s)
# Looking at (1): https://mantosdofutebol.com.br/2013/10/historia-camisa-flamengo/
# <Response [200]>
# Searching for flamengo on layer 1 done in 0.88 second(s)
# Looking at (1): https://en.wikipedia.org/w/index.php?title=Clube_de_Regatas_do_Flamengo
# <Response [200]>
# Searching for flamengo on layer 1 done in 2.45 second(s)
# Searching for flamengo on layer 2 done in 142.9 second(s)

# %%
for domain in scraper.found_domains:
    print(domain.__dict__)

# %%
for page in scraper.visited_pages:
        if 'match_sample' in page.__dict__.keys() and page.match_sample:
            print(page.match_sample)
# Out:
# JavaScript, C#, Scala, Visual Basic, Common Lisp, Scheme, Perl, PHP, Python, Ruby, Wolfram Language, Oz, and F#)
# JavaScriptCore
# JavaScript web frameworksHidden categories: Pages using Infobox software with unknown parameters
# JavaScript, Maple, Python, Ruby, Wolfram Language, Go, and Lua, support associative arrays as a primary container type
# JavaScript Libraries on the Web)/Subject()/Creator(LaTeX with hyperref package)/Producer(pdfTeX-1
# JavaScript Taking Both the High and Low Roads - O'Reilly Fluent 2014"},"longBylineText":{"runs":[{"text":"O'Reilly","navigationEndpoint":{"clickTrackingParams":"CEoQpDAYESITCKD3xPOhgegCFRJWkAodJMUC5zIHcmVsYXRlZA==","commandMetadata":{"webCommandMetadata":{"url":"/user/OreillyMedia","webPageType":"WEB_PAGE_TYPE_BROWSE","rootVe":3611}},"browseEndpoint":{"browseId":"UC3BGlwmI-Vk6PWyMt15dKGw","canonicalBaseUrl":"/user/OreillyMedia"}}}]},"publishedTimeText":{"simpleText":"5 anos atrás"},"viewCountText":{"simpleText":"42
# JavaScript الذي يأخذ ثلاثة قيمة ليجري عليها عمليته، ومن الشائع استخدام هذا المعامل كاختصارٍ للتعبير البرمجي if
# Inheritance and the prototype chain - JavaScript | MDN
# const - JavaScript | MDN
# JavaScript MIME Type
# JavaScript, PHP and Python
# JavaScript have remained very compatible throughout, and any new features are discussed and designed together
# JavaScript syntax
# JavaScript - Wikipedia
# JavaScript(TM)
# JavaScript (Computer program language)RAMEAU: JavaScript (langage de programmation)
# JavaScript frameworks
# Usage Statistics and Market Share of JavaScript Libraries for Websites, March 2020
# Function.prototype.bind() - JavaScript | MDN
# JavaScript WSH Engine
# JavaScript is increasingly being seen as a first class desktop programming language -- it us being used in Windows 8, mobile platforms, and for local web applications
# Javascript and XML
# JavaScript - Wikibooks, open books for an open world
# Pages that link to "JavaScript" - Wikipedia

# %%
scraper.get_search_history()
# Out:
# (('python',),
#  ('java',),
#  ('data',),
#  ('corona',),
#  ('javascript',),
#  ('flamengo',))

# %%
scraper.get_ranking('python')
# Out:
#                           netloc  \
# 188             en.wikipedia.org
# 286             en.wikipedia.org
# 194             en.wikipedia.org
# 227             en.wikipedia.org
# 32               docs.python.org
# 193             www.wikidata.org
# 63              hy.wikipedia.org
# 215           en.m.wikipedia.org
# 289              docs.python.org
# 269      www.stat.washington.edu
# 262             en.wikipedia.org
# 192              docs.python.org
# 259              docs.python.org
# 69              en.wikipedia.org
# 185              docs.python.org
# 101              docs.python.org
# 40              en.wikipedia.org
# 144  python-history.blogspot.com
# 1                 www.python.org
# 284             en.wikipedia.org
# 292              docs.python.org
# 233             en.wikipedia.org
# 41               docs.python.org
# 290              docs.python.org
# 242              docs.python.org
# 179             en.wikipedia.org
# 251             en.wikipedia.org
# 222               realpython.com
# 64               web.archive.org
# 149             en.wikipedia.org
# ..                           ...
# 206             en.wikipedia.org
# 182             en.wikipedia.org
# 183             en.wikipedia.org
# 202                  httpbin.org
# 191            radio.weblogs.com
# 223             en.wikipedia.org
# 132             en.wikipedia.org
# 131             en.wikipedia.org
# 114             en.wikipedia.org
# 87              en.wikipedia.org
# 95              en.wikipedia.org
# 100             en.wikipedia.org
# 107             en.wikipedia.org
# 108             en.wikipedia.org
# 240             en.wikipedia.org
# 110             en.wikipedia.org
# 111             en.wikipedia.org
# 113             en.wikipedia.org
# 115               www.troeger.eu
# 127             en.wikipedia.org
# 116             en.wikipedia.org
# 117             en.wikipedia.org
# 232             en.wikipedia.org
# 231             en.wikipedia.org
# 118                  archive.org
# 229             en.wikipedia.org
# 121             en.wikipedia.org
# 122             en.wikipedia.org
# 214          www.theinquirer.net
# 85              www.computer.org
#
#                                                                                                             url  \
# 188                      https://en.wikipedia.org/w/index.php?title=Python_(programming_language)&printable=yes
# 286                                                 https://en.wikipedia.org/wiki/Python_(programming_language)
# 194                                                   https://en.wikipedia.org/wiki/Python_syntax_and_semantics
# 227                                                             https://en.wikipedia.org/wiki/History_of_Python
# 32                                                                    https://docs.python.org/whatsnew/2.0.html
# 193                                                                        https://www.wikidata.org/wiki/Q28865
# 63                                                                         https://hy.wikipedia.org/wiki/Python
# 215                                   http://en.m.wikipedia.org/w/index.php?title=Python_(programming_language)
# 289                                                                           https://docs.python.org/devguide/
# 269                                                 https://www.stat.washington.edu/~hoytak/blog/whypython.html
# 262                                                                       https://en.wikipedia.org/wiki/IPython
# 192                                                           https://docs.python.org/2.7/library/stdtypes.html
# 259                                                               https://docs.python.org/3.9/whatsnew/3.9.html
# 69                                                                      https://en.wikipedia.org/wiki/Biopython
# 185                                         https://docs.python.org/3/library/stdtypes.html#truth-value-testing
# 101                                                            https://docs.python.org/reference/datamodel.html
# 40              https://en.wikipedia.org/w/index.php?title=Python_(programming_language)&action=edit&section=13
# 144                        https://python-history.blogspot.com/2010/08/why-pythons-integer-division-floors.html
# 1                                                                     https://www.python.org/dev/peps/pep-0605/
# 284                                                                         https://en.wikipedia.org/wiki/PyS60
# 292                                                      https://docs.python.org/3/howto/unicode.html#encodings
# 233                                                           https://en.wikipedia.org/wiki/Spam_(Monty_Python)
# 41                                                          https://docs.python.org/py3k/library/functions.html
# 290                                                              https://docs.python.org/library/functions.html
# 242                                                                   https://docs.python.org/3/using/unix.html
# 179                                                       https://en.wikipedia.org/wiki/Python_(disambiguation)
# 251                                                                       https://en.wikipedia.org/wiki/RPython
# 222                                                             https://realpython.com/interview-kenneth-reitz/
# 64                    https://web.archive.org/web/20070501105422/http://www.amk.ca/python/writing/gvr-interview
# 149                                             https://en.wikipedia.org/wiki/File:Python_logo_and_wordmark.svg
# ..                                                                                                          ...
# 206                                                              https://en.wikipedia.org/wiki/Code_readability
# 182                                         https://en.wikipedia.org/wiki/Special:BookSources/978-1-59059-881-8
# 183                https://en.wikipedia.org/wiki/Category:Articles_with_unsourced_statements_from_December_2019
# 202                                                                                        https://httpbin.org/
# 191                                                            http://radio.weblogs.com/0112098/2003/08/29.html
# 223                                                                  https://en.wikipedia.org/wiki/The_Inquirer
# 132                                                                      https://en.wikipedia.org/wiki/Aphorism
# 131                                                           https://en.wikipedia.org/wiki/Academic_conference
# 114                                                                   https://en.wikipedia.org/wiki/Prettyprint
# 87                                                      https://en.wikipedia.org/wiki/Graphical_user_interfaces
# 95                                                              https://en.wikipedia.org/wiki/Memory_allocation
# 100                                                                     https://en.wikipedia.org/wiki/Neologism
# 107                                                                          https://en.wikipedia.org/wiki/N900
# 108                                             https://en.wikipedia.org/wiki/Special:BookSources/9780201748840
# 240                                                       https://en.wikipedia.org/wiki/Wikipedia:Good_articles
# 110                                                                     https://en.wikipedia.org/wiki/Factorial
# 111                                                        https://en.wikipedia.org/wiki/Continuous_integration
# 113                                         https://en.wikipedia.org/wiki/Special:BookSources/978-1-4302-2415-0
# 115                                                               http://www.troeger.eu/teaching/pythonvm08.pdf
# 127                                                                          https://en.wikipedia.org/wiki/MIME
# 116                                                                    https://en.wikipedia.org/wiki/Automation
# 117                                                            https://en.wikipedia.org/wiki/Yukihiro_Matsumoto
# 232                                                 https://en.wikipedia.org/wiki/Expression_(computer_science)
# 231  https://en.wikipedia.org/wiki/Category:Articles_containing_potentially_dated_statements_from_November_2019
# 118                                                 https://archive.org/details/practicaljrubyon0000bini/page/3
# 229                                                                         https://en.wikipedia.org/wiki/Tuple
# 121                                                            https://en.wikipedia.org/wiki/Half-open_interval
# 122                                             https://en.wikipedia.org/wiki/TIOBE_Programming_Community_Index
# 214    https://www.theinquirer.net/inquirer/news/3035842/python-boss-guido-van-rossum-steps-down-after-30-years
# 85                                              http://www.computer.org/csdl/mags/cs/2011/02/mcs2011020009.html
#
#       score
# 188  100.00
# 286  100.00
# 194   85.47
# 227   85.47
# 32    84.62
# 193   84.05
# 63    82.62
# 215   82.62
# 289   78.06
# 269   77.49
# 262   76.92
# 192   74.93
# 259   74.36
# 69    74.07
# 185   73.79
# 101   73.50
# 40    72.93
# 144   72.65
# 1     72.65
# 284   70.94
# 292   70.09
# 233   69.52
# 41    68.95
# 290   68.95
# 242   68.95
# 179   68.95
# 251   68.38
# 222   67.24
# 64    66.38
# 149   66.10
# ..      ...
# 206   11.40
# 182   11.40
# 183   11.40
# 202   11.40
# 191   11.40
# 223   11.40
# 132   11.40
# 131   11.40
# 114   11.40
# 87    11.40
# 95    11.40
# 100   11.40
# 107   11.40
# 108   11.40
# 240   11.40
# 110   11.40
# 111   11.40
# 113   11.40
# 115   11.40
# 127   11.40
# 116   11.40
# 117   11.40
# 232   11.40
# 231   11.40
# 118   11.40
# 229   11.40
# 121   11.40
# 122   11.40
# 214    5.70
# 85     0.00
#
# [296 rows x 3 columns]

# %%
scraper.ignored_domains
conn.commit()

# %%
conn.close()
